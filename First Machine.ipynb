# %% [markdown]
# # Data Analysis With Python

# %%
# Importing Libaries ToolKit
#%load_ext cudf.pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploring a DataFrame

# %%
# Importing & Inspecting Data
data = pd.read_csv('/rideshare_kaggle.csv')

# %% [markdown]
#  id: Unique identifier for each record.
# timestamp: The timestamp of the Uber ride.
# hour, day, month: Time-related features extracted from the timestamp.
# datetime: A formatted datetime representation.
# timezone: Timezone information.
# source, destination: Locations related to the Uber ride.
# cab_type: The type of Uber cab used.
# product_id, name: Identification and name of the Uber product.
# price: The price of the Uber ride.
# distance: The distance of the Uber ride.
# surge_multiplier: Multiplier applied to the price during peak times.
# latitude, longitude: Geographic coordinates of the location.
# temperature, apparentTemperature: Actual and apparent temperature.
# short_summary, long_summary, icon: Weather-related information.
# precipIntensity, precipProbability: Intensity and probability of precipitation.
# humidity, windSpeed, windGust: Humidity, wind speed, and wind gust.
# windGustTime: Time of the maximum wind gust.
# visibility: Visibility during the ride.
# temperatureHigh, temperatureLow: Daily high and low temperatures.
# temperatureHighTime, temperatureLowTime: Time of daily high and low temperatures.
# apparentTemperatureHigh, apparentTemperatureLow: Apparent daily high and low temperatures.
# apparentTemperatureHighTime, apparentTemperatureLowTime: Time of apparent daily high and low temperatures.
# dewPoint, pressure, windBearing, cloudCover, uvIndex: Additional weather-related features.
# visibility.1: Another measure of visibility.
# ozone: Ozone levels.
# sunriseTime, sunsetTime: Times of sunrise and sunset.
# moonPhase: Phase of the moon.
# precipIntensityMax: Maximum precipitation intensity.
# uvIndexTime: Time of the maximum UV index.
# temperatureMin, temperatureMinTime, temperatureMax, temperatureMaxTime: Daily minimum and maximum temperatures.
# apparentTemperatureMin, apparentTemperatureMinTime, apparentTemperatureMax, apparentTemperatureMaxTime: Time and values for apparent daily minimum and maximum temperatures.

# %%
data.head(10)
# Out:
#                                      id     timestamp  hour  day  month  \
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2  981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
# 5  f6f6d7e4-3e18-4922-a5f5-181cdd3fa6f2  1.545071e+09    18   17     12
# 6  462816a3-820d-408b-8549-0b39e82f65ac  1.543209e+09     5   26     11
# 7  474d6376-bc59-4ec9-bf57-4e6d6faeb165  1.543780e+09    19    2     12
# 8  4f9fee41-fde3-4767-bbf1-a00e108701fb  1.543818e+09     6    3     12
# 9  8612d909-98b8-4454-a093-30bd48de0cb3  1.543316e+09    10   27     11
#
#               datetime          timezone            source  \
# 0  2018-12-16 09:30:07  America/New_York  Haymarket Square
# ...

# %%
data.columns
# Out:
# Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'cab_type', 'product_id', 'name', 'price',
#        'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'apparentTemperature', 'short_summary', 'long_summary',
#        'precipIntensity', 'precipProbability', 'humidity', 'windSpeed',
#        'windGust', 'windGustTime', 'visibility', 'temperatureHigh',
#        'temperatureHighTime', 'temperatureLow', 'temperatureLowTime',
#        'apparentTemperatureHigh', 'apparentTemperatureHighTime',
#        'apparentTemperatureLow', 'apparentTemperatureLowTime', 'icon',
#        'dewPoint', 'pressure', 'windBearing', 'cloudCover', 'uvIndex',
#        'visibility.1', 'ozone', 'sunriseTime', 'sunsetTime', 'moonPhase',
#        'precipIntensityMax', 'uvIndexTime', 'temperatureMin',
#        'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158227 entries, 0 to 158226
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           158227 non-null  object
#  1   timestamp                    158227 non-null  float64
#  2   hour                         158227 non-null  int64
#  3   day                          158227 non-null  int64
#  4   month                        158227 non-null  int64
#  5   datetime                     158227 non-null  object
#  6   timezone                     158227 non-null  object
#  7   source                       158227 non-null  object
#  8   destination                  158227 non-null  object
#  9   cab_type                     158227 non-null  object
#  10  product_id                   158227 non-null  object
#  11  name                         158227 non-null  object
# ...

# %%
data.shape
# Out:
# (158227, 57)

# %%
# Handle Missing Values
print(data.isna().sum())
# Out:
# id                                 0
# timestamp                          0
# hour                               0
# day                                0
# month                              0
# datetime                           0
# timezone                           0
# source                             0
# destination                        0
# cab_type                           0
# product_id                         0
# name                               0
# price                          12543
# distance                           0
# surge_multiplier                   0
# latitude                           0
# longitude                          0
# temperature                        0
# apparentTemperature                0
# short_summary                      0
# long_summary                       0
# precipIntensity                    0
# precipProbability                  0
# humidity                           0
# windSpeed                          0
# ...

# %%
threshold = len(data) * 0.05
print(threshold)
# Out:
# 7911.35

# %%
extra_cols = [ 'apparentTemperature', 'precipIntensity' ,
'humidity',
'windSpeed',
'apparentTemperatureHigh',
'dewPoint',
'precipIntensityMax',
'apparentTemperatureMax',
'cloudCover',
'moonPhase',
'windGustTime',
'visibility',
'temperatureHighTime' ,
'apparentTemperatureHighTime',
'apparentTemperatureLow' ,
'apparentTemperatureLowTime',
'temperatureMinTime' ,
'temperatureMaxTime',
'apparentTemperatureMin',
'apparentTemperatureMinTime', 'apparentTemperatureMaxTime',
'windBearing' ,
'sunriseTime',
'uvIndex' ,
'visibility.1',
'ozone',
'sunsetTime', 'uvIndexTime']
data = data.drop(extra_cols, axis=1)

# %%
data.columns
# Out:
# Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'cab_type', 'product_id', 'name', 'price',
#        'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'short_summary', 'long_summary', 'precipProbability', 'windGust',
#        'temperatureHigh', 'temperatureLow', 'temperatureLowTime', 'icon',
#        'pressure', 'temperatureMin', 'temperatureMax'],
#       dtype='object')

# %%
data.sample(10)
# Out:
#                                           id     timestamp  hour  day  month  \
# 47037   e495dc8a-5f91-411b-b512-55e338fd34c2  1.543721e+09     3    2     12
# 81823   b11231d7-ca4e-4bd0-84cf-456b22bc5912  1.543788e+09    22    2     12
# 83704   d133e2e5-fd6a-4702-adb3-a5df39bda06f  1.543327e+09    13   27     11
# 18300   f0d52452-a201-49b0-be91-859c9da28fba  1.543589e+09    14   30     11
# 46384   72595b3b-0bca-4a2e-a0bf-ffb6013e18a4  1.543359e+09    22   27     11
# 71138   b18dec54-f938-4ecb-ac3f-662ece0281d5  1.543422e+09    16   28     11
# 122280  e87388e1-43f0-48c6-bad2-66bfbb769ca5  1.543407e+09    12   28     11
# 25807   e9694dca-bd15-4ba7-b7b5-3a43259f2640  1.543596e+09    16   30     11
# 3880    aae7ae15-abfc-4486-887f-18128bee5c90  1.543444e+09    22   28     11
# 10572   957db6db-0048-4b7b-8400-96981f023224  1.545115e+09     6   18     12
#
#                    datetime          timezone            source  \
# ...

# %%
# Handle Missing Values
print(data.isna().sum())
# Out:
# id                        0
# timestamp                 0
# hour                      0
# day                       0
# month                     0
# datetime                  0
# timezone                  0
# source                    0
# destination               0
# cab_type                  0
# product_id                0
# name                      0
# price                 12543
# distance                  0
# surge_multiplier          0
# latitude                  0
# longitude                 0
# temperature               0
# short_summary             0
# long_summary              0
# precipProbability         0
# windGust                  0
# temperatureHigh           0
# temperatureLow            0
# temperatureLowTime        0
# icon                      1
# pressure                  1
# temperatureMin            1
# temperatureMax            1
# dtype: int64

# %%
cols_to_drop = data.columns[data.isna().sum() <= threshold]
print(cols_to_drop)
# Out:
# Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'cab_type', 'product_id', 'name', 'distance',
#        'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'short_summary', 'long_summary', 'precipProbability', 'windGust',
#        'temperatureHigh', 'temperatureLow', 'temperatureLowTime', 'icon',
#        'pressure', 'temperatureMin', 'temperatureMax'],
#       dtype='object')

# %%
#Plotting missing values
data.isna().sum().plot(kind="bar")
plt.show()

# %%
print(data.isna().sum())
data=data.dropna()
# Out:
# id                        0
# timestamp                 0
# hour                      0
# day                       0
# month                     0
# datetime                  0
# timezone                  0
# source                    0
# destination               0
# cab_type                  0
# product_id                0
# name                      0
# price                 12543
# distance                  0
# surge_multiplier          0
# latitude                  0
# longitude                 0
# temperature               0
# short_summary             0
# long_summary              0
# precipProbability         0
# windGust                  0
# temperatureHigh           0
# temperatureLow            0
# temperatureLowTime        0
# icon                      1
# pressure                  1
# temperatureMin            1
# temperatureMax            1
# dtype: int64

# %%
print(data.isna().sum())
# Out:
# id                    0
# timestamp             0
# hour                  0
# day                   0
# month                 0
# datetime              0
# timezone              0
# source                0
# destination           0
# cab_type              0
# product_id            0
# name                  0
# price                 0
# distance              0
# surge_multiplier      0
# latitude              0
# longitude             0
# temperature           0
# short_summary         0
# long_summary          0
# precipProbability     0
# windGust              0
# temperatureHigh       0
# temperatureLow        0
# temperatureLowTime    0
# icon                  0
# pressure              0
# temperatureMin        0
# temperatureMax        0
# dtype: int64

# %%
# check duplicated values
data.duplicated().sum()
# Out:
# 0

# %%
# find the outlier and handle
data.describe()
# Out:
#           timestamp         hour            day          month          price  \
# count  1.456830e+05  145683.0000  145683.000000  145683.000000  145683.000000
# mean   1.544036e+09      11.5608      17.892946      11.579869      16.601794
# std    6.875206e+05       6.9760       9.995366       0.493581       9.372328
# min    1.543204e+09       0.0000       1.000000      11.000000       2.500000
# 25%    1.543442e+09       5.0000      13.000000      11.000000       9.000000
# 50%    1.543729e+09      12.0000      17.000000      12.000000      13.500000
# 75%    1.544819e+09      17.0000      28.000000      12.000000      22.500000
# max    1.545161e+09      23.0000      30.000000      12.000000      92.000000
#
#             distance  surge_multiplier       latitude      longitude  \
# count  145683.000000     145683.000000  145683.000000  145683.000000
# mean        2.201639          1.015837      42.338125     -71.066166
# ...

# %%
# Find the outlier
sns.boxplot(data=data,x="price")
plt.show()

# %%
# Using the interquartile range
 # 75th percentile
seventy_fifth = data["price"].quantile(0.75)
# 25th percentile
twenty_fifth = data["price"].quantile(0.25)
# Interquartile range
data_iqr = seventy_fifth - twenty_fifth
print(data_iqr)
# Identifying outliers
# Upper threshold
upper = seventy_fifth + (1.5 * data_iqr)
# Lower threshold
lower = twenty_fifth - (1.5 * data_iqr)
print(upper, lower)
# Subsetting our data
print(data[(data["price"] < lower) | (data["price"] > upper)] \
[["hour","day","distance"]])
no_outliers = data[(data["price"] > lower) & (data["price"] < upper)]

print(no_outliers["price"].describe())
sns.boxplot(data=no_outliers,x="price")
plt.show()
# Out:
# 13.5
# 42.75 -11.25
#         hour  day  distance
# 706       10   28      3.25
# 707        2   16      3.25
# 769       17   14      4.76
# 1094      17    2      4.31
# 1318      16   16      5.33
# ...      ...  ...       ...
# 157884     9   26      3.44
# 157917    17   28      3.21
# 157970    19   15      1.06
# 158022    15   26      5.41
# 158158     2   30      1.11
#
# [1312 rows x 3 columns]
# count    144371.000000
# mean         16.291694
# std           8.795734
# min           2.500000
# 25%           9.000000
# 50%          13.500000
# 75%          22.500000
# max          42.500000
# Name: price, dtype: float64

# %% [markdown]
# # Data validation

# %%
#Converting andanalyzing categorical data
print(data.select_dtypes("object").head(0))
# Out:
# Empty DataFrame
# Columns: [id, datetime, timezone, source, destination, cab_type, product_id, name, short_summary, long_summary, icon]
# Index: []

# %%
data.dtypes
# Out:
# id                     object
# timestamp             float64
# hour                    int64
# day                     int64
# month                   int64
# datetime               object
# timezone               object
# source                 object
# destination            object
# cab_type               object
# product_id             object
# name                   object
# price                 float64
# distance              float64
# surge_multiplier      float64
# latitude              float64
# longitude             float64
# temperature           float64
# short_summary          object
# long_summary           object
# precipProbability     float64
# windGust              float64
# temperatureHigh       float64
# temperatureLow        float64
# temperatureLowTime      int64
# icon                   object
# pressure              float64
# temperatureMin        float64
# temperatureMax        float64
# dtype: object

# %%
print(data["price"].value_counts())
# Out:
# 7.0     11850
# 16.5    10112
# 10.5     9244
# 13.5     7572
# 9.0      7008
#         ...
# 81.5        1
# 87.5        1
# 64.5        1
# 62.0        1
# 57.0        1
# Name: price, Length: 128, dtype: int64

# %%
# find null values in column A
data['price'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 158221    False
# 158222    False
# 158223    False
# 158224    False
# 158225    False
# Name: price, Length: 145683, dtype: bool

# %%
data['price'].unique()
# Out:
# array([ 5.  , 11.  ,  7.  , 26.  ,  9.  , 16.5 , 10.5 ,  3.  , 27.5 ,
#        13.5 , 12.  , 16.  ,  7.5 ,  5.5 ,  3.5 ,  8.5 , 15.  , 20.5 ,
#        19.5 , 29.5 ,  9.5 , 22.  , 13.  , 17.  , 10.  , 34.  , 18.5 ,
#        36.  , 22.5 , 32.5 , 25.  , 27.  , 35.  ,  8.  , 23.5 , 14.  ,
#        26.5 , 38.5 , 23.  , 30.5 , 17.5 , 30.  , 36.5 , 12.5 , 33.5 ,
#        21.5 , 38.  , 18.  , 33.  , 32.  ,  6.5 , 11.5 , 31.5 , 28.5 ,
#        24.  , 29.  , 31.  , 42.5 , 41.  , 19.  , 52.5 , 67.5 , 15.5 ,
#        21.  , 45.5 , 28.  , 37.5 , 14.5 , 47.5 ,  4.5 , 40.5 , 55.  ,
#        42.  , 46.5 , 50.5 , 24.5 , 41.5 , 56.  , 25.5 , 39.  , 57.5 ,
#        20.  , 39.5 ,  6.  , 35.5 , 48.5 , 37.  , 45.  , 44.  , 34.5 ,
#         2.5 , 46.  , 48.  , 47.  , 54.  , 52.  , 62.  , 43.  , 43.5 ,
#        80.  , 65.  , 51.5 , 40.  , 49.5 , 58.  , 75.  , 62.5 , 92.  ,
#        87.  , 64.5 , 87.5 , 73.5 , 44.5 , 80.5 , 89.  , 53.  , 81.5 ,
# ...

# %%
price_counts =  data['price'].value_counts().head(10)

# Plotting the graph
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
price_counts.plot(kind='bar')
plt.xlabel('price')
plt.ylabel('Count')
plt.title('Top 10 Price with the Largest Occurrences')
plt.xticks(rotation=0)  # Rotate the x-axis labels if needed
plt.show()

# %%
# 1. Distribution of Trips Over Time
hours = data['hour'].value_counts()
# Create a bar plot using seaborn
plt.figure(figsize=(10, 5))
sns.barplot(x=hours.index, y=hours.values, color='blue')
# Set labels and title
plt.xlabel('Hours')
plt.ylabel('Number of Trips')
plt.title('Number of Trips vs Hours')
# Show the plot
plt.show()

# %%
# 2. Cab Type Comparison
plt.figure(figsize=(8, 8))
sns.countplot(x='cab_type', data=data)
plt.xlabel('Cab Type')
plt.ylabel('Number of Trips')
plt.title('Cab Type Comparison')
plt.show()

# %%
# 3. Geographic Distribution
plt.figure(figsize=(10, 10))
sns.scatterplot(x='longitude', y='latitude', hue='source', data=data)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographic Distribution of Trips')
plt.show()

# %%
# 4. Weather Impact
plt.figure(figsize=(12, 6))
sns.scatterplot(x='temperature', y='distance', data=data)
plt.xlabel('Temperature')
plt.ylabel('Distance')
plt.title('Weather Impact on Trips')
plt.show()

# %%
# 5. Product-wise Analysis (Top 10)
top_products = data['product_id'].value_counts().nlargest(10)
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x=top_products.index, y=top_products.values, palette='viridis')
plt.xlabel('Product ID')
plt.ylabel('Number of Trips')
plt.title('Top 10 Products by Number of Trips')
# Rotate x-axis labels
barplot.set_xticklabels(barplot.get_xticklabels(), rotation=90, ha='right')
plt.show()

# %%
# 6. Correlation Analysis
# This helps identify any features strongly correlated with the diagnosis
# Correlation Between Diagnosis and Other Features
numeric_columns = data.select_dtypes(include='number').columns
plt.figure(figsize = (20, 12))
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype = bool))
sns.heatmap(corr, mask = mask, linewidths = 1, annot = True, fmt = ".2f")
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23308\3983719926.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()

# %%
# 7. Time Series Analysis
plt.figure(figsize=(12, 6))
sns.lineplot(x='timestamp', y='distance', data=data)
plt.xlabel('Timestamp')
plt.ylabel('Distance')
plt.title('Time Series Analysis of Trips')
plt.show()

# %%
# 8. Weather Condition Analysis
plt.figure(figsize=(10, 6))
sns.boxplot(x='icon', y='distance', data=data)
plt.xlabel('Weather Icon')
plt.ylabel('Distance')
plt.title('Weather Condition Analysis')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 9. Surge Pricing Impact (Boxplot)
plt.figure(figsize=(8, 6))
sns.boxplot(x='surge_multiplier', y='distance', data=data, palette='Set2')
plt.xlabel('Surge Multiplier')
plt.ylabel('Distance')
plt.title('Surge Pricing Impact')
plt.show()

# %%
# 10. Statistical Distribution of Numeric Variables
plt.figure(figsize=(12, 6))
sns.histplot(data['distance'], kde=True)
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.title('Distribution of Distance')
plt.show()

# %% [markdown]
# # Predictive  Uber Price Prediction using Machine Learning

# %%
#Converting andanalyzing categorical data
print(data.select_dtypes("object").head(0))
# Out:
# Empty DataFrame
# Columns: [id, datetime, timezone, source, destination, cab_type, product_id, name, short_summary, long_summary, icon]
# Index: []

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['id'] = label_encoder.fit_transform(data['id'])
data['datetime'] = label_encoder.fit_transform(data['datetime'])
data['timezone'] = label_encoder.fit_transform(data['timezone'])
data['destination'] = label_encoder.fit_transform(data['destination'])
data['product_id'] = label_encoder.fit_transform(data['product_id'])
data['short_summary'] = label_encoder.fit_transform(data['short_summary'])
data['long_summary'] = label_encoder.fit_transform(data['long_summary'])
data['name'] = label_encoder.fit_transform(data['name'])

# %%
print("Class mapping of Name: ")
for i, item in enumerate(label_encoder.classes_):
    print(f"{item} --> {i}")
# Out:
# Class mapping of Name:
# Black --> 0
# Black SUV --> 1
# Lux --> 2
# Lux Black --> 3
# Lux Black XL --> 4
# Lyft --> 5
# Lyft XL --> 6
# Shared --> 7
# UberPool --> 8
# UberX --> 9
# UberXL --> 10
# WAV --> 11

# %%
data['source'] = label_encoder.fit_transform(data['source'])

print("Class mapping of Source: ")
for i, item in enumerate(label_encoder.classes_):
    print(item, "-->", i)
# Out:
# Class mapping of Source:
# Back Bay --> 0
# Beacon Hill --> 1
# Boston University --> 2
# Fenway --> 3
# Financial District --> 4
# Haymarket Square --> 5
# North End --> 6
# North Station --> 7
# Northeastern University --> 8
# South Station --> 9
# Theatre District --> 10
# West End --> 11

# %%
data['icon'] = label_encoder.fit_transform(data['icon'])

print("Class mapping of Icon: ")
for i, item in enumerate(label_encoder.classes_):
    print(item, "-->", i)
# Out:
# Class mapping of Icon:
#  clear-day  --> 0
#  clear-night  --> 1
#  cloudy  --> 2
#  fog  --> 3
#  partly-cloudy-day  --> 4
#  partly-cloudy-night  --> 5
#  rain  --> 6

# %%
data['cab_type'] = label_encoder.fit_transform(data['cab_type'])
print("Class mapping of Cabe_type: ")
for i, item in enumerate(label_encoder.classes_):
    print(item, "-->", i)
# Out:
# Class mapping of Cabe_type:
# Lyft --> 0
# Uber --> 1

# %%
len(data[data['cab_type']==1])
# Out:
# 75277

# %%
data.columns
# Out:
# Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'cab_type', 'product_id', 'name', 'price',
#        'distance', 'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'short_summary', 'long_summary', 'precipProbability', 'windGust',
#        'temperatureHigh', 'temperatureLow', 'temperatureLowTime', 'icon',
#        'pressure', 'temperatureMin', 'temperatureMax'],
#       dtype='object')

# %%
data.shape
# Out:
# (145683, 29)

# %%
seed=42
# Take a random sample of 20% of the rows from the DataFrame
sampled_data = data.sample(frac=0.1, random_state=seed)

# Display the sampled data
print(sampled_data.head())
# Out:
#             id     timestamp  hour  day  month  datetime  timezone  source  \
# 108418  141654  1.543813e+09     5    3     12     14121         0       7
# 129095   66220  1.543349e+09    20   27     11      2141         0       0
# 56540    66660  1.543756e+09    13    2     12     12553         0       7
# 86924    86222  1.543425e+09    17   28     11      3358         0       0
# 8626    117977  1.543438e+09    20   28     11      3635         0       9
#
#         destination  cab_type  ...  long_summary  precipProbability  windGust  \
# 108418            3         0  ...             0                0.0      2.44
# 129095            9         1  ...             2                0.0     11.74
# 56540             6         0  ...             9                1.0      7.01
# 86924             5         0  ...             4                0.0     14.90
# 8626              4         0  ...             4                0.0     13.00
#
# ...

# %%
data = sampled_data

# %%
data.shape
# Out:
# (14568, 29)

# %% [markdown]
# # Training Dataset

# %%
from   sklearn.feature_selection   import   RFE
from   sklearn.linear_model   import   LinearRegression
from   sklearn.tree   import   DecisionTreeRegressor
from   sklearn.ensemble   import   RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.svm import SVC



from sklearn.model_selection import train_test_split
x = data[data['cab_type']==1].drop(['price', 'cab_type'], axis=1)
y = data[data['cab_type']==1]['price']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)
x_train.columns
# Out:
# Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'product_id', 'name', 'distance',
#        'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'short_summary', 'long_summary', 'precipProbability', 'windGust',
#        'temperatureHigh', 'temperatureLow', 'temperatureLowTime', 'icon',
#        'pressure', 'temperatureMin', 'temperatureMax'],
#       dtype='object')

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Assuming 'data' is your DataFrame and 'cab_type', 'price' are columns in your DataFrame
# Check the size of the dataset
print("Original dataset size:", len(data))

# Select subset of data based on 'cab_type' value
filtered_data = data[data['cab_type'] == 1]

# Check the size of the filtered dataset
print("Filtered dataset size:", len(filtered_data))

# Check if there are enough samples for the specified test size
if len(filtered_data) > 1:
    x = filtered_data.drop(['price', 'cab_type'], axis=1)
    y = filtered_data['price']

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
    print("Train set size:", len(x_train))
    print("Test set size:", len(x_test))
    print("Features:", x_train.columns)
else:
    print("Not enough samples in the filtered dataset for the specified test size.")
# Out:
# Original dataset size: 14568
# Filtered dataset size: 7472
# Train set size: 5977
# Test set size: 1495
# Features: Index(['id', 'timestamp', 'hour', 'day', 'month', 'datetime', 'timezone',
#        'source', 'destination', 'product_id', 'name', 'distance',
#        'surge_multiplier', 'latitude', 'longitude', 'temperature',
#        'short_summary', 'long_summary', 'precipProbability', 'windGust',
#        'temperatureHigh', 'temperatureLow', 'temperatureLowTime', 'icon',
#        'pressure', 'temperatureMin', 'temperatureMax'],
#       dtype='object')

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Train the model
print("Linear Regression... ")
lr_model = LinearRegression()
lr_model = lr_model.fit(x_train,  y_train)

# Test the model
print(lr_model.score(x_test,  y_test))
# Out:
# Linear Regression...
# 0.6629135462760459

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Train the model
print("Linear Regression... ")
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)

# Test the model
y_pred = lr_model.predict(x_test)
r2 = r2_score(y_test, y_pred)
print("R-squared (unoptimized):", r2)

# Hyperparameter Tuning using GridSearchCV
param_grid = {
    'fit_intercept': [True, False],
    'positive': [True, False]  # Add 'positive' instead of 'normalize'
}

grid_search = GridSearchCV(LinearRegression(), param_grid, cv=5, scoring='r2')
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Train the model with the best parameters
lr_model_tuned = LinearRegression(**best_params)
lr_model_tuned.fit(x_train, y_train)

# Test the tuned model
y_pred_tuned = lr_model_tuned.predict(x_test)
r2_tuned = r2_score(y_test, y_pred_tuned)
print("R-squared (tuned):", r2_tuned)
# Out:
# Linear Regression...
# R-squared (unoptimized): 0.6629135462760459
# R-squared (tuned): 0.6629135462760459

# %%
print(lr_model_tuned.score(x_test,  y_test))
# Out:
# 0.6629135462760459

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Train the model
print("Decision Tree... ")
dt_model = DecisionTreeRegressor(random_state = 0, max_depth = 10)
dt_model.fit(x_train,  y_train)

# Test the model
print(dt_model.score(x_test,  y_test))
# Out:
# Decision Tree...
# 0.9185028230240992

# %%
from sklearn.model_selection import train_test_split, GridSearchCV,RandomizedSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Train the model
print("Decision Tree... ")
dt_model = DecisionTreeRegressor(random_state=0, max_depth=10)
dt_model.fit(x_train, y_train)

# Test the model
y_pred = dt_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (unoptimized):", mse)

# Hyperparameter Tuning using GridSearchCV
param_grid = {
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = RandomizedSearchCV(DecisionTreeRegressor(random_state=0), param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Train the model with the best parameters
dt_model_tuned = DecisionTreeRegressor(random_state=0, **best_params)
dt_model_tuned.fit(x_train, y_train)

# Test the tuned model
y_pred_tuned = dt_model_tuned.predict(x_test)
mse_tuned = mean_squared_error(y_test, y_pred_tuned)
print("Mean Squared Error (tuned):", mse_tuned)
# Out:
# Decision Tree...
# Mean Squared Error (unoptimized): 6.032807755032478
# Mean Squared Error (tuned): 4.187575929355918

# %%
print(dt_model_tuned.score(x_test,  y_test))
# Out:
# 0.9434300527262692

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
# Train the model
print("Random Forest... ")
rf_model = RandomForestRegressor(n_estimators = 20, random_state = 0)
rf_model.fit(x_train,  y_train)
# Test the model
print(rf_model.score(x_test,  y_test))
# Out:
# Random Forest...
# 0.9411592290002857

# %%
from sklearn.model_selection import train_test_split, GridSearchCV,RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Train the model
print("Random Forest... ")
rf_model = RandomForestRegressor(n_estimators=20, random_state=0)
rf_model.fit(x_train, y_train)

# Test the model
y_pred = rf_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (unoptimized):", mse)

# Hyperparameter Tuning using GridSearchCV
param_grid = {
    'n_estimators': [10, 20, 30],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = RandomizedSearchCV(RandomForestRegressor(random_state=0), param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Train the model with the best parameters
rf_model_tuned = RandomForestRegressor(random_state=0, **best_params)
rf_model_tuned.fit(x_train, y_train)

# Test the tuned model
y_pred_tuned = rf_model_tuned.predict(x_test)
mse_tuned = mean_squared_error(y_test, y_pred_tuned)
print("Mean Squared Error (tuned):", mse_tuned)
# Out:
# Random Forest...
# Mean Squared Error (unoptimized): 4.355673076923077
# Mean Squared Error (tuned): 3.9475140574789456

# %%
print(rf_model_tuned.score(x_test,  y_test))
# Out:
# 0.9466730476387465

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Train the model
print("GBM... ")
gbm_model = GradientBoostingRegressor(n_estimators = 200, max_depth = 5)
gbm_model.fit(x_train,  y_train)

# Test the model
print(gbm_model.score(x_test,  y_test))
# Out:
# GBM...
# 0.9485737474105601

# %%
from sklearn.model_selection import train_test_split, GridSearchCV,RandomizedSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Train the model
print("GBM... ")
gbm_model = GradientBoostingRegressor(n_estimators=200, max_depth=5)
gbm_model.fit(x_train, y_train)
y_pred = gbm_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (unoptimized):", mse)

# Hyperparameter Tuning using GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    #'learning_rate': [0.01, 0.1, 0.2],
    #'subsample': [0.8, 1.0]
}

grid_search = RandomizedSearchCV(GradientBoostingRegressor(random_state=0), param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Train the model with the best parameters
gbm_model_tuned = GradientBoostingRegressor(random_state=0, **best_params)
gbm_model_tuned.fit(x_train, y_train)

# Test the tuned model
y_pred_tuned = gbm_model_tuned.predict(x_test)
mse_tuned = mean_squared_error(y_test, y_pred_tuned)
print("Mean Squared Error (tuned):", mse_tuned)
# Out:
# GBM...
# Mean Squared Error (unoptimized): 3.6341858344511024
# C:\Users\ACER\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Mean Squared Error (tuned): 3.6314659934581788

# %%
print(gbm_model_tuned.score(x_test,  y_test))
# Out:
# 0.94997815443248

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Train the model
print("Support Vector Regression... ")
svr_model = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
svr_model.fit(x_train,  y_train)

# Test the model
print(svr_model.score(x_test,  y_test))
# Out:
# Support Vector Regression...
# -0.00013832691000681407

# %%
from sklearn.model_selection import train_test_split, GridSearchCV,RandomizedSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Train the model
print("Support Vector Regression... ")
svr_model = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
svr_model.fit(x_train, y_train)

# Test the model
y_pred = svr_model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (unoptimized):", mse)

# Hyperparameter Tuning using GridSearchCV
param_grid = {
    'kernel': ['linear', 'rbf', 'poly'],
    'C': [1, 10, 100],
    'gamma': [0.01, 0.1, 1],
    'epsilon': [0.1, 0.2, 0.5]
}

grid_search = GridSearchCV(SVR(), param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Train the model with the best parameters
svr_model_tuned = SVR(**best_params)
svr_model_tuned.fit(x_train, y_train)

# Test the tuned model
y_pred_tuned = svr_model_tuned.predict(x_test)
mse_tuned = mean_squared_error(y_test, y_pred_tuned)
print("Mean Squared Error (tuned):", mse_tuned)
# Out:
# Support Vector Regression...
# Mean Squared Error (unoptimized): 62.66311358317899

# %%
print(svr_model_tuned.score(x_test,  y_test))

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Train the model
print("AdaBoost Regression... ")
adaboost_model = AdaBoostRegressor(n_estimators=50, random_state=0, learning_rate=1.0)
adaboost_model.fit(x_train, y_train)

# Test the model
predictions = adaboost_model.predict(x_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)

# Calculate R-squared
r2 = r2_score(y_test, predictions)
print("R-squared:", r2)
# Out:
# AdaBoost Regression...
# Mean Squared Error: 15.471162264239119
# R-squared: 0.791000127922229

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Define the parameter grid to search
param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.001, 0.01, 0.1, 1.0],
}

# Create AdaBoostRegressor
adaboost_model = AdaBoostRegressor(random_state=0)

# Create GridSearchCV
grid_search = GridSearchCV(adaboost_model, param_grid, scoring='neg_mean_squared_error', cv=5)
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Train the model with the best parameters
best_adaboost_model = AdaBoostRegressor(**best_params, random_state=0)
best_adaboost_model.fit(x_train, y_train)

# Test the model
predictions = best_adaboost_model.predict(x_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)

# Calculate R-squared
r2 = r2_score(y_test, predictions)
print("R-squared:", r2)
# Out:
# Best Parameters: {'learning_rate': 0.01, 'n_estimators': 150}
# Mean Squared Error: 7.82284915101465
# R-squared: 0.8943211606263783

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Train the model
print("Gradient Boosting Regression... ")
gradient_boost_model = GradientBoostingRegressor(n_estimators=50, random_state=0, learning_rate=0.1)
gradient_boost_model.fit(x_train, y_train)

# Test the model
predictions = gradient_boost_model.predict(x_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)

# Calculate R-squared
r2 = r2_score(y_test, predictions)
print("R-squared:", r2)

# Calculate Root Mean Squared Error
rmse = mean_squared_error(y_test, predictions, squared=False)
print("Root Mean Squared Error:", rmse)
# Out:
# Gradient Boosting Regression...
# Mean Squared Error: 3.8919658897348888
# R-squared: 0.9474234476251455
# Root Mean Squared Error: 1.9728066022129207

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5]
}

# Create the Gradient Boosting Regressor
gradient_boost_model = GradientBoostingRegressor(random_state=0)

# Create GridSearchCV
grid_search = GridSearchCV(gradient_boost_model, param_grid, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the model to the training data
grid_search.fit(x_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Test the model with the best parameters
best_model = grid_search.best_estimator_
predictions = best_model.predict(x_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)

# Calculate R-squared
r2 = r2_score(y_test, predictions)
print("R-squared:", r2)

# Calculate Root Mean Squared Error
rmse = mean_squared_error(y_test, predictions, squared=False)
print("Root Mean Squared Error:", rmse)
# Out:
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 50}
# Mean Squared Error: 3.8030800495197203
# R-squared: 0.9486242061019301
# Root Mean Squared Error: 1.9501487249745133

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Define the pipeline with multiple models
pipeline = Pipeline([
    ('linear_regression', LinearRegression()),
    ('decision_tree', DecisionTreeRegressor(random_state=0, max_depth=10)),
    ('random_forest', RandomForestRegressor(n_estimators=20, random_state=0)),
    ('gradient_boosting', GradientBoostingRegressor(n_estimators=200, max_depth=5)),
    ('adaboost', AdaBoostRegressor(n_estimators=50, random_state=0, learning_rate=1.0)),
    ('svr', SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.1)),
])

# Train and test each model in the pipeline
for step_name, model in pipeline.steps:
    print(f"{step_name}...")

    if 'classifier' in step_name:
        # For classifiers
        model.fit(x_train, y_train)
        predictions = model.predict(x_test)
        accuracy = accuracy_score(y_test, predictions)
        print(f"Accuracy: {accuracy:.4f}")
    else:
        # For regressors
        model.fit(x_train, y_train)
        score = model.score(x_test, y_test)
        print(f"Score: {score:.4f}")

# Access individual models from the pipeline if needed
linear_regression_model = pipeline.named_steps['linear_regression']
decision_tree_model = pipeline.named_steps['decision_tree']
# ... (access other models as needed)
adaboost_model = pipeline.named_steps['adaboost']
# Out:
# linear_regression...
# Score: 0.6629
# decision_tree...
# Score: 0.9185
# random_forest...
# Score: 0.9412
# gradient_boosting...
# Score: 0.9484
# adaboost...
# Score: 0.7910
# svr...
# Score: -0.0000

# %%
from sklearn.model_selection import GridSearchCV

# Define hyperparameter grids for each model
param_grid = {
    'linear_regression__normalize': [True, False],  # Example hyperparameter for Linear Regression
    'decision_tree__max_depth': [5, 10, 15],
    'random_forest__n_estimators': [10, 20, 50],
    'gradient_boosting__n_estimators': [100, 200, 300],
    'adaboost__n_estimators': [30, 50, 70],
    'adaboost__learning_rate': [0.1, 0.5, 1.0],
    'svr__C': [1, 10, 100],
    'svr__gamma': [0.01, 0.1, 1.0],
}

# Perform GridSearchCV for each model in the pipeline
for step_name, model in pipeline.steps:
    print(f"Tuning hyperparameters for {step_name}...")

    if step_name in param_grid:
        grid_search = GridSearchCV(model, param_grid[step_name], cv=5, scoring='neg_mean_squared_error')
        grid_search.fit(x_train, y_train)

        # Print the best hyperparameters and corresponding score
        print(f"Best {step_name} hyperparameters: {grid_search.best_params_}")
        print(f"Best {step_name} negative mean squared error: {grid_search.best_score_:.4f}")

        # Update the pipeline with the best hyperparameters
        pipeline.named_steps[step_name].set_params(**grid_search.best_params_)

# Retrain and test each model with the tuned hyperparameters
for step_name, model in pipeline.steps:
    print(f"{step_name}...")

    if 'classifier' in step_name:
        # For classifiers
        model.fit(x_train, y_train)
        predictions = model.predict(x_test)
        accuracy = accuracy_score(y_test, predictions)
        print(f"Accuracy: {accuracy:.4f}")
    else:
        # For regressors
        model.fit(x_train, y_train)
        score = model.score(x_test, y_test)
        print(f"Score: {score:.4f}")
# Out:
# Tuning hyperparameters for linear_regression...
# Tuning hyperparameters for decision_tree...
# Tuning hyperparameters for random_forest...
# Tuning hyperparameters for gradient_boosting...
# Tuning hyperparameters for adaboost...
# Tuning hyperparameters for svr...
# linear_regression...
# Score: 0.6629
# decision_tree...
# Score: 0.9185
# random_forest...
# Score: 0.9412
# gradient_boosting...
# Score: 0.9486
# adaboost...
# Score: 0.7910
# svr...
# Score: -0.0000

# %% [markdown]
# # Finish
